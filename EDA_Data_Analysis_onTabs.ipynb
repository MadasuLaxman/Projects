# %% [markdown]
# ## Data_Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("tablets.csv")

# %%
df
# Out:
#      Unnamed: 0   Brands              Models            Colors Actual_price  \
# 0             0    REDMI         REDMI Pad 6        Mint Green      ₹34,499
# 1             1   realme        realme Pad 2  Imagination Grey      ₹28,999
# 2             2   Lenovo      Lenovo Tab M10         Iron Grey      ₹22,000
# 3             3    APPLE           GB ROM 10        Space Grey      ₹32,900
# 4             4  SAMSUNG  SAMSUNG Galaxy Tab              Gray      ₹28,799
# ..          ...      ...                 ...               ...          ...
# 475         475    APPLE      APPLE iPad Pro        Space Grey          NaN
# 476         476    APPLE      APPLE iPad Pro            Silver          NaN
# 477         477   Lenovo      Lenovo Tab M10   Platinum Gre...          NaN
# 478         478    APPLE      APPLE iPad Pro        Space Grey          NaN
# 479         479    APPLE      APPLE iPad Pro            Silver          NaN
#
# ...

# %%
#dropping unnamed column.
df.drop("Unnamed: 0",axis = 1,inplace = True)

# %% [markdown]
# ## Structural Errors/corrupted Data

# %%
#replacing with nan values and identified models.
df.loc[df["Models"] == "GB ROM 10", "Models"] = np.nan
df.loc[df["Models"] == "GB ROM 9", "Models"] = np.nan
df.loc[df["Models"] == "GB RAM 32", "Models"] = np.nan
df.loc[df["Models"] == "Micromax Fantabulet\xa0F666", "Models"] = "Micromax Fantabulet"

# %%
#IN colors we have unknown data so i'm replacing with random colors.
df.loc[df["Colors"] == '2nd Gen with Google Assistant 4 GB RAM 128 GB ROM 10.3 inch with Wi-Fi...', "Colors"] = "Rose Gold"
df.loc[df["Colors"] == 'Apple iPad Air 2 32 GB 9.7 inch with Wi-Fi Only', "Colors"] = "Rose Gold"
df.loc[df["Colors"] == 'Apple iPad Air 2 16 GB 9.7 inch with Wi-Fi+4G', "Colors"] = "Rose Gold"
df.loc[df["Colors"] == 'Apple iPad Pro 32 GB 9.7 inch with Wi-Fi Only', "Colors"] = "Rose Gold"

# %%
df.loc[df["Colors"] == 'Apple iPad Pro 32 GB 9.7 inch with Wi-Fi+4G', "Colors"] = "Rose Gold"
df.loc[df["Colors"] == 'Lenovo Tab Ideapad Duet 3 with Bluetooth Keyboard and Digital Pen 4 GB RAM 128 GB ROM 10.3 inches with...', "Colors"] = "Rose Gold"
df.loc[df["Colors"] == '2nd Gen with Active Pen 4 GB RAM 128 GB ROM 10.3 inches with Wi-Fi Only Tabl...', "Colors"] = "Aurora Black"
df.loc[df["Colors"] == "HP Slate 7 Voice Tab", "Colors"] = "Aurora Black"

# %%
df.loc[df["Colors"] == 'Lenovo A7-30 Tablet', "Colors"] = "Aurora Black"
df.loc[df["Colors"] == "Samsung Galaxy Tab E", "Colors"] = "Aurora Black"
df.loc[df["Colors"] == "Wi-Fi+4G", "Colors"] = "Aurora Black"
df.loc[df["Colors"] == "Apple iPad mini 4 128 GB 7.9 inch with Wi-Fi+4G", "Colors"] = "Glowing Grey"

# %%
#IN RAM we have unknown data so i'm replacing with random RAM.
df.loc[df["RAM_in_GB"] == 5.0, "RAM_in_GB"] =16.0
df.loc[df["RAM_in_GB"] == 0., "RAM_in_GB"] =12.0
df.loc[df["RAM_in_GB"] == 512.0, "RAM_in_GB"] =12.0
df.loc[df["RAM_in_GB"] == 1.0, "RAM_in_GB"] =12.0

# %%
df["RAM_in_GB"].unique()
# Out:
# array([ 6.,  3., nan,  4., 12.,  8., 16.,  2.])

# %%
#IN ROM we have unknown data so i'm replacing with random ROM.
df.loc[df["ROM_in_GB"] == 1.0, "ROM_in_GB"] =16.0
df.loc[df["ROM_in_GB"] == 2.0, "ROM_in_GB"] =64.0

# %%
df["ROM_in_GB"].unique()
# Out:
# array([128.,  32.,  64., 256.,  16.,  nan, 512.,   8.])

# %% [raw]
# #IN front_cameraMP we have unknown data so i'm replacing with random front_cameraMP.
# df.loc[df["front_cameraMP"] == 3.0, "front_cameraMP"] = 8.0
# df.loc[df["front_cameraMP"] == 7.0, "front_cameraMP"] = 12.0

# %%
df["front_camera_in_MP"].unique()
# Out:
# array([ 8.,  5., 12., nan,  7.,  2.,  3.])

# %%
#IN back_cameraMP we have unknown data so i'm replacing with random back_cameraMP.
df.loc[df["back_camera_in_MP"] == 0.0, "back_camera_in_MP"] = 4.0

# %%
df["back_camera_in_MP"].unique()
# Out:
# array([ 8., 13.,  5., 12.,  4., nan,  2., 16.])

# %%
#IN Ratings we have unknown data so i'm replacing with random Ratings.
df.loc[df["Ratings"] == "442", "Ratings"] = '4.2'
df.loc[df["Ratings"] == "413", "Ratings"] = '4.2'
df.loc[df["Ratings"] == "494", "Ratings"] = '4.2'
df.loc[df["Ratings"] == "444", "Ratings"] = '4.2'
df.loc[df["Ratings"] == "445", "Ratings"] = '4.4'
df.loc[df["Ratings"] == "1,7", "Ratings"] = '1.7'
df.loc[df["Ratings"] == "2,1", "Ratings"] = '2.1'
df.loc[df["Ratings"] == "7,2", "Ratings"] = '4.2'
df.loc[df["Ratings"] == "3,8", "Ratings"] = '3.8'
df.loc[df["Ratings"] == "4,8", "Ratings"] = '4.8'

# %%
df["Ratings"].unique()
# Out:
# array(['4.4', '4.5', '4.2', '4.6', '4.3', '4.7', '3.8', '3.6', '3.9',
#        '3.7', '4.1', '1.7', '2.1', '4.8'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brands                  480 non-null    object
#  1   Models                  446 non-null    object
#  2   Colors                  480 non-null    object
#  3   Actual_price            399 non-null    object
#  4   Discount_in_percentage  460 non-null    object
#  5   Price                   480 non-null    object
#  6   RAM_in_GB               317 non-null    float64
#  7   ROM_in_GB               474 non-null    float64
#  8   Display_in_inches       363 non-null    float64
#  9   Batterys_in_mAh         252 non-null    float64
#  10  Processor               417 non-null    object
#  11  os                      298 non-null    object
#  12  front_camera_in_MP      445 non-null    float64
#  13  back_camera_in_MP       468 non-null    float64
# ...

# %% [markdown]
# ## Missing values

# %%
#checking missing values in percentaile
df.isnull().sum()/len(df)*100
# Out:
# Brands                     0.000000
# Models                     7.083333
# Colors                     0.000000
# Actual_price              16.875000
# Discount_in_percentage     4.166667
# Price                      0.000000
# RAM_in_GB                 33.958333
# ROM_in_GB                  1.250000
# Display_in_inches         24.375000
# Batterys_in_mAh           47.500000
# Processor                 13.125000
# os                        37.916667
# front_camera_in_MP         7.291667
# back_camera_in_MP          2.500000
# warranty                  10.000000
# Ratings                    0.000000
# dtype: float64

# %%
#checking missing values
df.isna().sum()
# Out:
# Brands                      0
# Models                     34
# Colors                      0
# Actual_price               81
# Discount_in_percentage     20
# Price                       0
# RAM_in_GB                 163
# ROM_in_GB                   6
# Display_in_inches         117
# Batterys_in_mAh           228
# Processor                  63
# os                        182
# front_camera_in_MP         35
# back_camera_in_MP          12
# warranty                   48
# Ratings                     0
# dtype: int64

# %%
#Replacing brand names with original brand

# %%
df["Brands"]= df["Brands"].replace("Mi","REDMI")

# %%
df["Brands"]= df["Brands"].replace("Apple","APPLE")

# %%
df["Brands"]= df["Brands"].replace("Samsung","SAMSUNG")

# %%
#filling missing values

# %%
brand_to_battery = {
    'SAMSUNG': 7040.0,
    'APPLE': 8827.0, 
    'Lenovo': 5100.0,
    'OnePlus': 9510.0,
    'iball': 4300.0,
    'Alcatel': 4080.0,
    'Nokia': 8200.0,
    'Acer': 6600.0,
    'TCL': 8000.0
}

df['Batterys_in_mAh'] = df['Batterys_in_mAh'].fillna(df['Brands'].map(brand_to_battery))

# %%
brand_to_os = {
    'OnePlus': 'Android',
    'Oppo': 'Android',
    'SAMSUNG': 'Android',
    'APPLE': 'iOS',
    'MOTOROLA': 'Android',
    'Lenovo': 'Android',
    'Acer': 'Android',
    'Swipe': 'Android',
    'Nokia': 'Android',
    'Huawei': 'Android',
    'Alcatel': 'Android',
    'Honor': 'Android',
    'HP': 'Windows',
    'Panasonic': 'Android',
    'Micromax': 'Android',
    'iball':  'Android'
}
df['os'] = df['os'].fillna(df['Brands'].map(brand_to_os))

# %%
brand_to_processor = {
    'SAMSUNG': 'Exynos',
    'APPLE': 'Apple M1',
    'Lenovo': 'MediaTek',
    'Swipe': 'MediaTek',
    'iball': 'Intel',
    'Alcatel': 'Mediatek',
    'Elevn': 'Intel',
    'Micromax': 'Mediatek',
    'TCL': 'Mediatek'
}
df['Processor'] = df['Processor'].fillna(df['Brands'].map(brand_to_processor))

# %%
df['RAM_in_GB'].values
# Out:
# array([ 6.,  6.,  3., nan,  4.,  3.,  4.,  4.,  6.,  6.,  6.,  6.,  6.,
#        nan,  6.,  4., nan, 12.,  4.,  6.,  8.,  8.,  4.,  4.,  6.,  8.,
#         8.,  6.,  6., nan,  6.,  4.,  8.,  4.,  8.,  8.,  6.,  6.,  6.,
#         6., nan,  4.,  6.,  4., nan,  3.,  6.,  4.,  4.,  3.,  6., nan,
#        nan,  3.,  6.,  6.,  4.,  4., nan, nan,  6.,  4., nan,  8., nan,
#        nan, nan,  4.,  4.,  6.,  4.,  4., nan, nan, nan,  4.,  3., nan,
#        nan, 16., nan, 16., nan,  3., nan, nan,  4., nan, nan, 16., nan,
#         4.,  4., nan,  4., nan, nan, nan,  3., 16., 16., nan, nan, nan,
#        nan,  4., nan, nan,  4., nan,  3., nan,  8.,  3., nan, nan, nan,
#        nan,  3.,  3.,  3., nan, nan,  4., nan,  8., nan,  3., nan, nan,
#        nan, nan, nan, nan,  6., nan,  3., nan, nan, nan,  4., nan, nan,
#        nan, nan, nan,  4.,  3., nan, nan,  4., nan,  3.,  4.,  3., 16.,
#        16.,  6.,  4.,  3.,  4.,  2., nan,  4.,  4., nan, nan,  6.,  6.,
# ...

# %%
df[df['RAM_in_GB'].isna()]
# Out:
#     Brands          Models      Colors Actual_price Discount_in_percentage  \
# 3    APPLE             NaN  Space Grey      ₹32,900                24% off
# 13   APPLE             NaN      Silver      ₹59,999                51% off
# 16   APPLE             NaN        Blue      ₹29,999                 6% off
# 29   APPLE             NaN  Space Grey      ₹39,999                30% off
# 40   APPLE             NaN      Silver      ₹32,900                60% off
# ..     ...             ...         ...          ...                    ...
# 474  APPLE  APPLE iPad Pro  Space Grey          NaN                35% off
# 475  APPLE  APPLE iPad Pro  Space Grey          NaN                72% off
# 476  APPLE  APPLE iPad Pro      Silver          NaN                30% off
# 478  APPLE  APPLE iPad Pro  Space Grey          NaN                45% off
# 479  APPLE  APPLE iPad Pro      Silver          NaN                    NaN
#
# ...

# %%
df["RAM_in_GB"].fillna(0,inplace = True)

# %%
df.drop("Models", axis=1,inplace=True)
df.drop("warranty",axis = 1,inplace = True)

# %%
df["ROM_in_GB"].mode()[0]
# Out:
# 64.0

# %%
df["ROM_in_GB"].fillna(df["ROM_in_GB"].mode()[0],inplace = True)
df["Display_in_inches"].fillna(df["Display_in_inches"].mode()[0],inplace = True)
df["front_camera_in_MP"].fillna(8.0,inplace = True)
df["back_camera_in_MP"].fillna(df["back_camera_in_MP"].mode()[0],inplace = True)

# %%
df["Discount_in_percentage"].fillna("36% off",inplace = True)

# %%
df["Actual_price"].fillna("₹35,999",inplace = True)

# %%
df.isna().sum()
# Out:
# Brands                    0
# Colors                    0
# Actual_price              0
# Discount_in_percentage    0
# Price                     0
# RAM_in_GB                 0
# ROM_in_GB                 0
# Display_in_inches         0
# Batterys_in_mAh           0
# Processor                 0
# os                        0
# front_camera_in_MP        0
# back_camera_in_MP         0
# Ratings                   0
# dtype: int64

# %% [markdown]
# ## Duplicate values

# %%
#Identifing duplicates 
df.duplicated().sum()
# Out:
# 2

# %%
#removing duplicates from the dataset
df.drop_duplicates(keep = "first",inplace = True)

# %%
df
# Out:
#       Brands            Colors Actual_price Discount_in_percentage    Price  \
# 0      REDMI        Mint Green      ₹34,499                50% off  ₹16,999
# 1     realme  Imagination Grey      ₹28,999                36% off  ₹18,499
# 2     Lenovo         Iron Grey      ₹22,000                59% off   ₹8,999
# 3      APPLE        Space Grey      ₹32,900                24% off  ₹24,900
# 4    SAMSUNG              Gray      ₹28,799                44% off  ₹15,999
# ..       ...               ...          ...                    ...      ...
# 475    APPLE        Space Grey      ₹35,999                72% off    ₹1,17
# 476    APPLE            Silver      ₹35,999                30% off    ₹1,17
# 477   Lenovo   Platinum Gre...      ₹35,999                46% off  ₹15,999
# 478    APPLE        Space Grey      ₹35,999                45% off    ₹1,03
# 479    APPLE            Silver      ₹35,999                36% off    ₹1,03
#
# ...

# %% [markdown]
# ## Type casting

# %%
df.head()
# Out:
#     Brands            Colors Actual_price Discount_in_percentage    Price  \
# 0    REDMI        Mint Green      ₹34,499                50% off  ₹16,999
# 1   realme  Imagination Grey      ₹28,999                36% off  ₹18,499
# 2   Lenovo         Iron Grey      ₹22,000                59% off   ₹8,999
# 3    APPLE        Space Grey      ₹32,900                24% off  ₹24,900
# 4  SAMSUNG              Gray      ₹28,799                44% off  ₹15,999
#
#    RAM_in_GB  ROM_in_GB  Display_in_inches  Batterys_in_mAh       Processor  \
# 0        6.0      128.0              10.61           8000.0      Octa Core1
# 1        6.0      128.0              11.50           8360.0   Mediatek G991
# 2        3.0       32.0              10.10           5000.0  Mediatek Helio
# 3        0.0       64.0              10.20           8827.0      A13 Bionic
# 4        4.0       64.0              10.50           7040.0      Octa Core1
#
#             os  front_camera_in_MP  back_camera_in_MP Ratings
# ...

# %%
df['Price'][0].replace("₹","").replace(",","")
# Out:
# '16999'

# %%
#removing special charecters from prices
df['Price'] = [i.replace("₹","").replace(",","") for i in df['Price']]

# %%
#converting data types into original datatypes
df['Price'] = df['Price'].astype("int")

# %%
df['Price'] = np.where(df['Price']<3500,df['Price']*1000,df['Price'])

# %%
df['RAM_in_GB'] = df['RAM_in_GB'].astype('int')
df['ROM_in_GB'] = df['ROM_in_GB'].astype('int')
df['Batterys_in_mAh'] = df['Batterys_in_mAh'].astype('int')
df['Ratings'] = df['Ratings'].astype('float')

# %%
df['back_camera_in_MP'] = df['back_camera_in_MP'].astype('int')

# %%
df['front_camera_in_MP'] = df['front_camera_in_MP'].astype('int')

# %%
df['Discount_in_percentage'] = df['Discount_in_percentage'].str.replace('% off', '').astype("float")

# %%
df['Actual_price'] = [i.replace("₹","").replace(",","") for i in df['Actual_price']]

# %%
df['Actual_price'] = df['Actual_price'].astype("int")

# %%
df.dtypes
# Out:
# Brands                     object
# Colors                     object
# Actual_price                int32
# Discount_in_percentage    float64
# Price                       int32
# RAM_in_GB                   int32
# ROM_in_GB                   int32
# Display_in_inches         float64
# Batterys_in_mAh             int32
# Processor                  object
# os                         object
# front_camera_in_MP          int32
# back_camera_in_MP           int32
# Ratings                   float64
# dtype: object

# %%
df.head()
# Out:
#     Brands            Colors  Actual_price  Discount_in_percentage  Price  \
# 0    REDMI        Mint Green         34499                    50.0  16999
# 1   realme  Imagination Grey         28999                    36.0  18499
# 2   Lenovo         Iron Grey         22000                    59.0   8999
# 3    APPLE        Space Grey         32900                    24.0  24900
# 4  SAMSUNG              Gray         28799                    44.0  15999
#
#    RAM_in_GB  ROM_in_GB  Display_in_inches  Batterys_in_mAh       Processor  \
# 0          6        128              10.61             8000      Octa Core1
# 1          6        128              11.50             8360   Mediatek G991
# 2          3         32              10.10             5000  Mediatek Helio
# 3          0         64              10.20             8827      A13 Bionic
# 4          4         64              10.50             7040      Octa Core1
#
#             os  front_camera_in_MP  back_camera_in_MP  Ratings
# ...

# %%
df.describe(exclude=[np.number])
# Out:
#        Brands      Colors            Processor       os
# count     478         478                  478      478
# unique     20          86                   72       14
# top     APPLE  Space Grey  Qualcomm Snapdragon  Android
# freq      196          86                   49      149

# %%
#describing statistical methods 
df.describe()
# Out:
#         Actual_price  Discount_in_percentage          Price   RAM_in_GB  \
# count     478.000000              478.000000     478.000000  478.000000
# mean    46587.991632               24.767782   46203.368201    3.548117
# std     36225.757417               18.926163   43180.595567    3.957424
# min      4999.000000                1.000000    3800.000000    0.000000
# 25%     24990.000000                6.000000   13999.000000    0.000000
# 50%     35999.000000               21.000000   27999.000000    3.000000
# 75%     59900.000000               38.000000   67874.000000    4.000000
# max    206900.000000               80.000000  212000.000000   16.000000
#
#         ROM_in_GB  Display_in_inches  Batterys_in_mAh  front_camera_in_MP  \
# count  478.000000         478.000000       478.000000          478.000000
# mean   110.610879          10.486791      7385.667364            6.941423
# std    116.593774           1.226202      1841.662235            3.216298
# ...

# %%
#describing statistical methods 
numeric_columns = ['Actual_price', 'Price', 'Discount_in_percentage','Batterys_in_mAh',"Ratings"]
subset_df = df[numeric_columns]
subset_df.describe()
# Out:
#         Actual_price          Price  Discount_in_percentage  Batterys_in_mAh  \
# count     478.000000     478.000000              478.000000       478.000000
# mean    46587.991632   46203.368201               24.767782      7385.667364
# std     36225.757417   43180.595567               18.926163      1841.662235
# min      4999.000000    3800.000000                1.000000      2500.000000
# 25%     24990.000000   13999.000000                6.000000      6000.000000
# 50%     35999.000000   27999.000000               21.000000      8200.000000
# 75%     59900.000000   67874.000000               38.000000      8827.000000
# max    206900.000000  212000.000000               80.000000     10200.000000
#
#           Ratings
# count  478.000000
# mean     4.382008
# std      0.391217
# min      1.700000
# 25%      4.200000
# 50%      4.500000
# 75%      4.600000
# max      4.800000

# %%
#cleaned dataset saved into Tabs_Data.
df.to_csv("tabs.csv")

# %% [markdown]
# ## Data visualization

# %% [markdown]
# ### Univariate Analysis

# %%
df
# Out:
#       Brands            Colors  Actual_price  Discount_in_percentage   Price  \
# 0      REDMI        Mint Green         34499                    50.0   16999
# 1     realme  Imagination Grey         28999                    36.0   18499
# 2     Lenovo         Iron Grey         22000                    59.0    8999
# 3      APPLE        Space Grey         32900                    24.0   24900
# 4    SAMSUNG              Gray         28799                    44.0   15999
# ..       ...               ...           ...                     ...     ...
# 475    APPLE        Space Grey         35999                    72.0  117000
# 476    APPLE            Silver         35999                    30.0  117000
# 477   Lenovo   Platinum Gre...         35999                    46.0   15999
# 478    APPLE        Space Grey         35999                    45.0  103000
# 479    APPLE            Silver         35999                    36.0  103000
#
# ...

# %% [markdown]
# ### Numerical plots

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Price'], bins=20, kde=True)
plt.title('Distribution of Prices')
plt.xlabel('Prices')
plt.ylabel('Frequency')
plt.show()

# %%
df["Price"].mean()
# Out:
# 46203.36820083682

# %% [markdown]
# + The hist plot shows the distribution of tab Prices from the minimum to the maximum.
# + Most frequent Prices are between 4,000 to 25,000.
# + Least frequent Prices are above 125,000 to 250,000 and beyond.
# + The average Prices of the tabs is close to 47,000.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Actual_price'], bins=20, kde=True,color = "skyblue")
plt.title('Distribution of Actual Prices')
plt.xlabel('Prices')
plt.ylabel('Frequency')
plt.show()

# %%
df["Actual_price"].mean()
# Out:
# 46587.99163179917

# %% [markdown]
# + The hist plot shows the distribution of tab Actual Prices from the minimum to the maximum.
# + Most frequent Prices are between 10,000 to 45,000.
# + Least frequent Prices are above 120,000 to 250,000 and beyond.
# + The average Prices of the tabs is close to 47,000.

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['RAM_in_GB'], bins=range(1, 17), kde=True, color='purple')
plt.title('Distribution of RAM')
plt.xlabel('RAM')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# + The hist plot shows the distribution of RAMs from the minimum to the maximum.
# + Most frequent RAMs are between 2GB to 6GB.
# + Least frequent RAMs are above 8GB and beyond.
# + The RAMs range of 2GB to 16GB, the frequency varies from 0 to 90.
# + 4GB RAMs counts upto 85.

# %%
# Histogram: Distribution of Prices
plt.figure(figsize=(8,6))
sns.histplot(df['ROM_in_GB'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Prices')
plt.xlabel('ROM')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# + The hist plot shows the distribution of ROMs from the minimum to the maximum.
# + Most frequent ROMs are between 8GB to 128GB.
# + Least frequent ROMs are 512GB and beyond.
# + The ROMs range of 4GB to 512GB, the frequency varies from 0 to 170.
# + 64GB ROMs counts upto 165.

# %%
df.columns
# Out:
# Index(['Brands', 'Colors', 'Actual_price', 'Discount_in_percentage', 'Price',
#        'RAM_in_GB', 'ROM_in_GB', 'Display_in_inches', 'Batterys_in_mAh',
#        'Processor', 'os', 'front_camera_in_MP', 'back_camera_in_MP',
#        'Ratings'],
#       dtype='object')

# %%
df["Batterys_in_mAh"].plot(kind = 'hist',
               xlabel = "Batterys",
               color = '#d6d5cb',
               title =  'Histogram of Batterys')
# Out:
# <Axes: title={'center': 'Histogram of Batterys'}, xlabel='Batterys', ylabel='Frequency'>

# %% [markdown]
# + The histogram illustrates the capacity distribution of Tab Batteries.
#
# + The battery capacity range of 1800 mAh to 10500 mAh, the frequency varies from 0 to 280.
#
# + Analyzing the histogram, it becomes evident that the most common battery capacity falls within the range of 8700 to 9500 mAh, with a corresponding frequency of 280.
#
# + Additionally, it can be observed that a significant portion of batteries lies within the range of 1800 mAh to 3500 mAh.

# %% [markdown]
# ### categorical plots

# %%
plt.figure(figsize=(8, 6))

os_counts = df["os"].value_counts()

sns.set_palette("pastel")

# Plotting the bar chart
ax = os_counts.plot(kind='bar', color='#a8e7f0', edgecolor='black', linewidth=1)

ax.set_xlabel('Operating System')
ax.set_ylabel('Count')
ax.set_title('Bar Plot of Operating System')

# Adding the count values on top of each bar
for i, count in enumerate(os_counts):
    ax.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# + The Bar plot shows the distribution of operating systems.
# + Most frequent operating system is **Android**.
# + Least frequent operating systems are **(ios11 and windows10 )**.
# + The operating systems frequency varies from 0 to 150.
# + In this plot we can see that Android tabs are 149.

# %%
os_counts = df['os'].value_counts()

largest_os = os_counts.nlargest()
plt.figure(figsize=(8, 6))
sns.barplot(x=largest_os.index, y=largest_os)
plt.title('Operating System with the Largest Count')
plt.xlabel('Operating System')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# + The Bar plot shows the distributions of Top 5 operating systems.
# + The top 5 operating systems are Android, Android 11, Android 12, ios 12, ipados 16.

# %%
top_brands_counts = df["Brands"].value_counts().nlargest()

sns.set_palette("Set3")

ax = top_brands_counts.plot(kind='bar', color='#8bbabb', edgecolor='black', linewidth=1)

# Adding labels and title
ax.set_xlabel('Brands')
ax.set_ylabel('Count')
ax.set_title('Top 5 Brands in the DataFrame')

for i, count in enumerate(top_brands_counts):
    ax.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# + The Bar plot shows the distributions of Top 5 Brands in the DataFrame.
# + The top 5 Brands are Apple, Samsung, Lenovo, realme, Alcatel
# + The Brands frequency varies from 0 to 200.
# + In this plot we can see that Apple Brands are 196.

# %%
top_processors = df["Processor"].value_counts().nlargest(10)

sns.set_palette("viridis")

ax = top_processors.plot(kind='bar', edgecolor='black', linewidth=1)

ax.set_xlabel('Processor')
ax.set_ylabel('Count')
ax.set_title('Top 10 Processors in the Dataset')

for i, count in enumerate(top_processors):
    ax.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# + The Bar plot shows the distributions of Top 10 processors in the DataFrame.
# + The top 5 Brands are Qualcomm Snapdragon, Apple M1, A12x Bionic, A14 Bionic, Apple M2
# + The processors frequency varies from 0 to 50.
# + In this plot we can see that Qualcomm Snapdragon processor tabs are 196.

# %%
# Bar Plot: Distribution of Brands
df.Brands.value_counts().plot(kind='bar', edgecolor='black', linewidth=1)
plt.title('Distribution of Brands')
plt.xlabel('Brands')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Count Plot: Count of occurrences for each Brand
sns.countplot(data=df, x='Brands', palette='viridis')
plt.title('Count of Occurrences for Each Brand')
plt.xlabel('Brands')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Count Plot: Count of occurrences for each Color
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='Colors', palette='muted')
plt.title('Count of Occurrences for Each Color')
plt.xlabel('Colors')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Count Plot: Count of occurrences for each Operating System (os)
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='os', palette='pastel')
plt.title('Count of Occurrences for Each Operating System')
plt.xlabel('Operating Systems')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Count Plot: Count of occurrences for each Processor
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='Processor', palette='Set2')
plt.title('Count of Occurrences for Each Processor')
plt.xlabel('Processor')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### categorical & categorical

# %%
top_brands = df['Brands'].value_counts().nlargest(10).index

df_top_brands = df[df['Brands'].isin(top_brands)]

plt.figure(figsize=(12, 8))
sns.countplot(data=df_top_brands, x='Brands', hue="os", palette="viridis", saturation=0.75, dodge=True)

plt.title('Count of Operating System by Top 10 Brands')
plt.xlabel('Brands')
plt.ylabel('Count')

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# + This count plot shows that Apple Brands have more operating systems comparing with other brands.
# + And Lenovo and Samsung brands have second most operating systems.
# + Honor, iball, Alcatel brands have only one operating system that is **Android**.

# %% [markdown]
# ### categorical & Numerical

# %%
df.groupby(by='Brands')['Discount_in_percentage'].max().nlargest(20).plot.bar()
plt.ylabel('Discount_in_percentage')
plt.title("Brand wise Discounts")
plt.show()

# %% [markdown]
# + This groupby shows that brands and discount for the tabs.
# + The Apple and Samsung brands are giving high dicount comparing to other brands.
# + And Acer and Panasonic brands are giving less discount in the DataFrame.
# + The frequency varies from 0 to 80.

# %%
mean_prices_by_brand = df.groupby('Brands')['Price'].mean()

sns.set_palette("muted")

ax = mean_prices_by_brand.plot(kind='bar', figsize=(8, 6), edgecolor='black', linewidth=1)

plt.xlabel('Brands')
plt.ylabel('Mean Prices')
plt.title('Average Prices by Brand')

for i, mean_price in enumerate(mean_prices_by_brand):
    ax.text(i, mean_price + 0.1, f"₹{mean_price:.2f}", ha='center', va='bottom', rotation=90)

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# + This barplot shows the distribution of average prices by brands.
# + The Apple and Samsung brands are high average prices comparing to other brands.
# + And Micromax and Tcl brands are low average prices in the DataFrame.
# + The Apple brand average price is 84,666.
# + The frequency varies from 0 to 85000.

# %%
price_range_by_brand = df.groupby('Brands')['Price'].agg(["min", "max"])

sns.set_palette("Set2")

ax = price_range_by_brand.plot(kind='bar', figsize=(12, 10), edgecolor='black', linewidth=1)

ax.set_xlabel('Brands')
ax.set_ylabel('Price')
ax.set_title('Price Range by Brand')

for i, (min_price, max_price) in enumerate(zip(price_range_by_brand['min'], price_range_by_brand['max'])):
    ax.text(i, min_price - 0.2, f"{min_price:1}", ha='center', va='bottom', color='blue')
    ax.text(i, max_price + 0.2, f"{max_price:1}", ha='center', va='bottom', color='red')

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# + The barplot shows the distribution of min and max prices by brands.
# + The Apple brands are starting from 25000 to 212000 prices comparing to other brands.
# + And Micromax brands are starting from 4799 to 8499 prices in the DataFrame.
# + The Eleven, panasonic and Lava brands are have only  one tab.
# + The frequency varies from 0 to 215000.

# %%
plt.figure(figsize=(8,6 ))
sns.barplot(x='Brands', y='front_camera_in_MP', data=df, color='skyblue', label='Front Camera')
sns.barplot(x='Brands', y='back_camera_in_MP', data=df, color='orange', label='Back Camera')

plt.title('Camera Comparison Across Brands')
plt.xlabel('Brands')
plt.ylabel('Camera Megapixels')

plt.legend()

plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# ### Numerical & Numerical

# %%
# Scatter Plot: Prices vs. Ratings
sns.scatterplot(data=df, x='Price', y='Ratings', color='blue')
plt.title('Scatter Plot: Prices vs. Ratings')
plt.xlabel('Prices')
plt.ylabel('Ratings')
plt.show()

# %%
sns.scatterplot(data=df, x='Discount_in_percentage', y='Actual_price', color='red')
plt.title('Scatter Plot: Discount_in_percentage vs. Actual price')
plt.xlabel('Discount_in_percentage')
plt.ylabel('Actual price')
plt.show()

# %%
# Scatter Plot: Prices vs. DiscountPrice
sns.scatterplot(data=df, x='Price', y='Actual_price', color='green')
plt.title('Scatter Plot: Prices vs. Actual price')
plt.xlabel('Prices')
plt.ylabel('Actual price')
plt.show()

# %%
df[['Price','ROM_in_GB']].corr()
# Out:
#               Price  ROM_in_GB
# Price      1.000000   0.406354
# ROM_in_GB  0.406354   1.000000

# %%
df[['Price','RAM_in_GB']].corr()
# Out:
#              Price  RAM_in_GB
# Price      1.00000   -0.03553
# RAM_in_GB -0.03553    1.00000

# %%
df.corr(numeric_only = True)
# Out:
#                         Actual_price  Discount_in_percentage     Price  \
# Actual_price                1.000000               -0.081301  0.174134
# Discount_in_percentage     -0.081301                1.000000 -0.070596
# Price                       0.174134               -0.070596  1.000000
# RAM_in_GB                  -0.117774                0.050994 -0.035530
# ROM_in_GB                   0.107220                0.054226  0.406354
# Display_in_inches           0.086095                0.028566  0.454786
# Batterys_in_mAh             0.206887               -0.050190  0.604227
# front_camera_in_MP          0.139813               -0.018753  0.528711
# back_camera_in_MP           0.210349               -0.120349  0.623898
# Ratings                     0.165629               -0.043716  0.568943
#
#                         RAM_in_GB  ROM_in_GB  Display_in_inches  \
# Actual_price            -0.117774   0.107220           0.086095
# ...

# %% [markdown]
# ### Multivarite Analysis

# %%
df.dtypes
# Out:
# Brands                     object
# Colors                     object
# Actual_price                int32
# Discount_in_percentage    float64
# Price                       int32
# RAM_in_GB                   int32
# ROM_in_GB                   int32
# Display_in_inches         float64
# Batterys_in_mAh             int32
# Processor                  object
# os                         object
# front_camera_in_MP          int32
# back_camera_in_MP           int32
# Ratings                   float64
# dtype: object

# %%
numeric_columns_of_interest = ['Actual_price', 'Price', 'Discount_in_percentage','Batterys_in_mAh',"Ratings"]

subset_df = df[numeric_columns_of_interest]

plt.figure(figsize=(8, 6))
sns.heatmap(subset_df.corr(), annot=True, cmap='coolwarm', fmt='.2f', cbar=True)

plt.yticks(rotation=0)

plt.title('Correlation Matrix Heatmap')

plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f', cbar=True)

# Rotating y-axis labels for better readability
plt.yticks(rotation=0)

# Adding title
plt.title('Correlation Matrix Heatmap')

# Display the plot
plt.show()

# %%
# Pair Plot: Visualizing pairwise relationships between numerical variables
sns.pairplot(df[['Price', 'Ratings', 'Actual_price', 'Discount_in_percentage']])
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()

# %% [markdown]
# ### Q: What is the overall range of tablet prices in the dataset?

# %% [markdown]
# The dataset reveals a diverse range of tablet prices, with the highest priced tablet at **2,12,000** and the lowest priced tablet at **3,800.**

# %% [markdown]
# ### Q: How do different operating systems impact tablet prices?

# %% [markdown]
# The analysis suggests that tablets running **IOS** tend to have higher prices compared to tablets with **Android**.

# %% [markdown]
# ### Q: Top 10 costly tabs before discount and their selling price?

# %%
df.sort_values(by = "Actual_price",ascending = False).head(10)
# Out:
#       Brands        Colors  Actual_price  Discount_in_percentage   Price  \
# 236    APPLE    Space Grey        206900                    58.0  103000
# 208    APPLE        Silver        198900                    46.0   93900
# 204    APPLE        Silver        198900                    38.0  186000
# 229    APPLE        Silver        191900                    69.0   79900
# 219  SAMSUNG          Pink        191900                     3.0   38999
# 109    APPLE    Space Grey        184900                     3.0   78465
# 101    APPLE        Purple        184900                    42.0   72999
# 207    Swipe  Glacier Blue        176900                    58.0    9999
# 210   Huawei  Deepsea Blue        176900                     3.0    5499
# 110  SAMSUNG        Silver        170900                     3.0   13999
#
#      RAM_in_GB  ROM_in_GB  Display_in_inches  Batterys_in_mAh  \
# 236          6        512               10.1             8827
# ...

# %% [markdown]
# + The above data shows that top 10 high rated tablets.
# + Apple, Samsung, Swipe, Huawei brands are high costed tablets.

# %% [markdown]
# ### Q: Is there a correlation between battery capacity and the price of tablets?

# %% [markdown]
# yes there is a correlation between battery capacity and the price of tablets

# %% [markdown]
# ### Q: Are there particular brands that consistently offer higher or lower prices?
#
# Yes, our analysis indicates variations in pricing trends among different brands. For instance, Apple tends to position itself at a higher price point, while Realme offers more budget-friendly options.

# %%
d = df.sort_values(by = "Actual_price",ascending = False).head(10)

# %%
d.Brands.value_counts().plot(kind = "bar")
plt.ylabel("count")
plt.title("Top 10 high cost tabs")
plt.show()

# %% [markdown]
# #### Q: What does the 'Price' column with the largest count reveal about the distribution of tablet prices in the dataset?

# %%
p_counts = df['Price'].value_counts()

largest_p = p_counts.nlargest()
sns.barplot(x=largest_p.index, y=largest_p)
plt.title('Price with the Largest Count')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Q: What insights can be gained by filtering tablets in the dataset with prices between 10,000 and 25,000, RAM capacity of 6GB or more, a discount percentage of 50% or higher, and at least 128GB of ROM?

# %%
#In this dataset with prices between 10,000 and 25,000, RAM capacity of 6GB or more, a discount percentage of 50% or higher, and at least 128GB of ROM?

df[((df.Price>10000) & (df.Price<25000)) & (df.RAM_in_GB >= 6) & (df.Discount_in_percentage>=50) & (df.ROM_in_GB >=128)]
# Out:
#       Brands             Colors  Actual_price  Discount_in_percentage  Price  \
# 0      REDMI         Mint Green         34499                    50.0  16999
# 10    realme       Glowing Grey         35999                    50.0  24999
# 14  MOTOROLA     Modernist Teal         32900                    50.0  18999
# 20    realme  Inspiration Green         31999                    50.0  20999
# 21    realme   Imagination Grey         32999                    50.0  20999
# 28    realme   Imagination Grey         41999                    50.0  18499
# 39    realme               Grey         25999                    50.0  12999
# 60     REDMI   Moonlight Silver         76999                    56.0  16999
#
#     RAM_in_GB  ROM_in_GB  Display_in_inches  Batterys_in_mAh  \
# 0           6        128              10.61             8000
# 10          6        128              10.10             8340
# 14          6        128              10.10             7700
# ...

# %% [markdown]
# ### Q: which tabs satisfies all the above requirement?

# %%
a = df[((df.Price>10000) & (df.Price<25000)) & (df.RAM_in_GB >= 6) & (df.Discount_in_percentage>=50) & (df.ROM_in_GB >=128)]

# %%
value_counts = a.Brands.value_counts()

plt.figure(figsize=(8, 6))
ax = value_counts.plot(kind='bar', color=plt.cm.Paired.colors)
plt.title('Bar Chart of Brands')
plt.xlabel('Brands')
plt.ylabel('Count')

for i, count in enumerate(value_counts):
    ax.text(i, count + 0.1, str(int(count)), ha='center', va='bottom')  # Convert count to int and then to str

plt.xticks(rotation=1, ha='right')
plt.show()

# %% [markdown]
# + The bar plot shows the distribution of prices by brands, range of 10000 to 25000.
# + And 6GB RAM and 128 GB ROM with above 50% discount.
# + In this plot 5 realme, 2 redmi, 1 Motorola brands are there.
# + This tabs are the top selling products in the DataFrame.

# %%
df.Discount_in_percentage.unique()
# Out:
# array([50., 36., 59., 24., 44., 54., 60., 48., 51.,  2.,  6., 46., 58.,
#        30., 32.,  3., 41., 56., 16.,  9., 17., 14.,  8., 40., 43.,  7.,
#         5., 21.,  1., 42., 15., 64., 12., 20., 10., 37., 26., 11., 57.,
#         4., 45., 25., 69., 52., 38., 35., 19., 13., 77., 33., 28., 18.,
#        39., 27., 22., 65., 34., 47., 66., 29., 23., 73., 80., 72.])
